# %%
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image

# Se carga el dataset como un dataframe.
df = pd.read_csv('/Users/jarmireciomartinez/Doctorado_Python/Pruebas_regresion/df_results.csv', sep=",")
df = df[['Name','Score']]
df
# Out:
#         Name     Score
# 0       nnet  0.211067
# 1         lr  0.815474
# 2        dtr  0.153155
# 3         rf  0.112986
# 4        svm  0.574814
# 5      bayes  0.813329
# 6        knn  0.255293
# 7         gp  0.285422
# 8        sgd  0.799175
# 9     voting  0.126095
# 10  stacking  0.112666

# %%
name = df['Name'].tolist()
score = df['Score'].tolist()

# Figure Size 
fig, ax = plt.subplots(figsize = (10,5)) 
  
# Bar Plot 
ax.bar(name, score, 0.5)   

    
for i, v in enumerate(score):
    ax.text(i-0.4, v+0.02,round(score[i],4), fontsize=12)
  
# Remove axes splines 
for s in ['top', 'bottom', 'left', 'right']: 
    ax.spines[s].set_visible(False)

# Add x, y gridlines 
ax.grid(b = True, color ='grey', 
        linestyle ='-.', linewidth = 0.5, 
        alpha = 0.2)
  
# Show Plot 
plt.show()

# %%
#Random Forest prediction
Image(filename='y_pred_rf.png')

# %%
#Random Forest error
Image(filename='error_rf.png')

# %%
#Stacking prediction
Image(filename='y_pred_stack.png')

# %%
#Stacking error
Image(filename='error_stack.png')
